# %%
import pandas as pd
import numpy as np
df=pd.read_csv("airlines_flights_data.csv")
df
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cmap="viridis")
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (300153, 12)

# %%
df.columns
# Out:
# Index(['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# index                 int64
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
for i in ["duration","days_left","price"]:
    print(i,":",df[i].unique(),"\n")
# Out:
# duration : [ 2.17  2.33  2.25  2.08 12.25 16.33 11.75 14.5  15.67  3.75  2.5   5.83
#   8.    6.   14.67 16.17 18.   23.17 24.17  8.83  4.5  15.25 11.   19.08
#  22.83 26.42 17.75 19.58 26.67 15.17 20.83 11.42 22.25 26.   21.75  3.83
#   4.42  7.67  8.33 10.42 23.75 19.5   6.5  12.42 21.08 28.17 28.25  9.25
#  17.92  7.08 13.83  7.58 15.83 24.42  4.17  4.25  5.08 29.33 17.   27.17
#  24.75  5.75 12.75 13.75 17.83  5.5  23.83  5.   26.5  12.83  8.92 11.17
#  12.17 15.58 15.75  7.92 13.25 16.   22.75  6.33  7.25 30.08 18.25  6.08
#   2.   12.33  3.5  10.25 14.17 25.58  4.08  9.75  6.67  9.67 10.08 12.58
#   7.    8.25 15.5  10.17 23.5  25.75 11.5  21.42 14.25  7.75  5.33  5.67
#   4.75 19.33  6.25 10.33  9.08 15.42  4.83 25.83  7.5  27.58 28.42  6.42
#  24.58 16.5  11.33 24.83 14.92 26.08  5.42 28.5  27.33  8.67 20.42 20.08
#   5.92 20.58 26.17 17.5  18.33 21.83 26.83 13.42 19.25 23.58 23.92 12.08
#  14.42 25.92 18.58 13.08  4.58 21.58 10.5  11.67  8.58 24.67 14.75 17.17
# ...

# %%
df.tail(3)
# Out:
#          index  airline  flight source_city departure_time stops arrival_time  \
# 300150  300150  Vistara  UK-832     Chennai  Early_Morning   one        Night
# 300151  300151  Vistara  UK-828     Chennai  Early_Morning   one      Evening
# 300152  300152  Vistara  UK-822     Chennai        Morning   one      Evening
#
#        destination_city     class  duration  days_left  price
# 300150        Hyderabad  Business     13.83         49  79099
# 300151        Hyderabad  Business     10.00         49  81585
# 300152        Hyderabad  Business     10.08         49  81585

# %%
import matplotlib.pyplot as plt
sns.countplot(x="departure_time",data=df)
plt.xticks(rotation=90)
plt.title("departure_time")
plt.show()
sns.countplot(x="arrival_time",data=df)
plt.title("arrival_time")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="departure_time",y="price",data=df,palette="plasma")
plt.xlabel("departure_time")
plt.ylabel("ticket price")
plt.xticks(rotation=90)
plt.show()
#plt.subplots(212)
plt.figure(figsize=(5,5))
sns.barplot(x="arrival_time",y="price",data=df,color="c")
plt.xlabel("arrival_time")
plt.ylabel("ticket price")
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="source_city",y="price",data=df,palette="plasma")
plt.xlabel("source_city")
plt.ylabel("ticket price")
plt.xticks(rotation=90)
plt.show()
#plt.subplots(212)
plt.figure(figsize=(5,5))
sns.barplot(x="destination_city",y="price",data=df,palette="plasma")
plt.xlabel("destination_city")
plt.ylabel("ticket price")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="class",y="price",data=df,palette="plasma")
plt.xlabel("class")
plt.ylabel("ticket price")
plt.title("economy vs business ticket price")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x="airline",y="price",data=df,palette="plasma")
plt.xlabel("airline")
plt.ylabel("ticket price")
plt.title("airline selling price")
plt.xticks(rotation=90)
plt.show()

# %%
df.head(2)
# Out:
#    index   airline   flight source_city departure_time stops arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero        Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero      Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953

# %%
a=df.groupby(["departure_time"])
b=a["departure_time"].count()
b
# Out:
# departure_time
# Afternoon        47794
# Early_Morning    66790
# Evening          65102
# Late_Night        1306
# Morning          71146
# Night            48015
# Name: departure_time, dtype: int64

# %%
c=df.groupby(["arrival_time"])
d=c["arrival_time"].count()
d
# Out:
# arrival_time
# Afternoon        38139
# Early_Morning    15417
# Evening          78323
# Late_Night       14001
# Morning          62735
# Night            91538
# Name: arrival_time, dtype: int64

# %%
df[df["duration"]==df["duration"].max()]
# Out:
#          index    airline  flight source_city departure_time        stops  \
# 193889  193889  Air_India  AI-672     Chennai        Evening  two_or_more
# 194359  194359  Air_India  AI-672     Chennai        Evening          one
#
#        arrival_time destination_city    class  duration  days_left  price
# 193889      Evening        Bangalore  Economy     49.83          2  23891
# 194359      Evening        Bangalore  Economy     49.83          9  17538

# %%
df[df["duration"]==df["duration"].min()]
# Out:
#          index airline   flight source_city departure_time stops  \
# 115869  115869  Indigo   6E-357   Bangalore          Night  zero
# 115943  115943  Indigo   6E-357   Bangalore          Night  zero
# 116010  116010  Indigo   6E-357   Bangalore          Night  zero
# 116081  116081  Indigo   6E-357   Bangalore          Night  zero
# 116163  116163  Indigo   6E-357   Bangalore          Night  zero
# 116236  116236  Indigo   6E-357   Bangalore          Night  zero
# 116322  116322  Indigo   6E-357   Bangalore          Night  zero
# 116411  116411  Indigo   6E-357   Bangalore          Night  zero
# 116496  116496  Indigo   6E-357   Bangalore          Night  zero
# 116656  116656  Indigo   6E-357   Bangalore          Night  zero
# 116835  116835  Indigo   6E-357   Bangalore          Night  zero
# 116924  116924  Indigo   6E-357   Bangalore          Night  zero
# 117019  117019  Indigo   6E-357   Bangalore          Night  zero
# ...

# %%
df.groupby("airline")["price"].max()
# Out:
# airline
# AirAsia       31917
# Air_India     90970
# GO_FIRST      32803
# Indigo        31952
# SpiceJet      34158
# Vistara      123071
# Name: price, dtype: int64

# %%
df.groupby("airline")["price"].min()
# Out:
# airline
# AirAsia      1105
# Air_India    1526
# GO_FIRST     1105
# Indigo       1105
# SpiceJet     1106
# Vistara      1714
# Name: price, dtype: int64

# %%
df1=df[(df["airline"]=="Vistara")&(df["source_city"]=="Delhi")&(df["destination_city"]=="Hyderabad")]
df1
# Out:
#          index  airline  flight source_city departure_time stops  \
# 28780    28780  Vistara  UK-859       Delhi        Morning  zero
# 28789    28789  Vistara  UK-829       Delhi  Early_Morning  zero
# 28790    28790  Vistara  UK-899       Delhi      Afternoon  zero
# 28795    28795  Vistara  UK-871       Delhi          Night  zero
# 28796    28796  Vistara  UK-951       Delhi      Afternoon   one
# ...        ...      ...     ...         ...            ...   ...
# 221863  221863  Vistara  UK-963       Delhi        Morning   one
# 221864  221864  Vistara  UK-985       Delhi        Evening   one
# 221865  221865  Vistara  UK-985       Delhi        Evening   one
# 221866  221866  Vistara  UK-955       Delhi        Evening   one
# 221867  221867  Vistara  UK-955       Delhi        Evening   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 28780       Afternoon        Hyderabad   Economy      2.17          1   6060
# ...

# %%
print("the average price of vistara airline for a flight from delhi to hyderabad in business class is",df["price"].mean())
# Out:
# the average price of vistara airline for a flight from delhi to hyderabad in business class is 20889.660523133203

# %%
sns.heatmap(df.cov(numeric_only=True),annot=True,cmap="viridis",fmt="g")
plt.title("covariance")
plt.show()
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="viridis",fmt="g")
plt.title("correlation")
plt.show()
